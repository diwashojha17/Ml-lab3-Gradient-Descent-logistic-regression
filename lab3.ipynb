# %% [markdown]
# <a href="https://colab.research.google.com/github/diwashojha17/Ml-lab3-Gradient-Descent-logistic-regression/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gradient Descent

# %%
data = {
    'X':[1,2,3,4,5],
    'Y':[2,5,7,8,9]
}
import pandas as pd
df=pd.DataFrame(data)
print(df)
# Out:
#    X  Y
# 0  1  2
# 1  2  5
# 2  3  7
# 3  4  8
# 4  5  9

# %%
x=df['X']
y=df['Y']

# %%
a=0
b=0
alpha=0.01
n=len(x)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score
for i in range(10):
  y_pred=a+b*x
  error=y-y_pred
  mse=mean_squared_error(y,y_pred)
  print("mse:",mse)
  a_grad = -(2/n) * np.sum(error)
  b_grad = -(2/n) * np.sum(error * x)
  a=a-alpha*a_grad
  b=b-alpha*b_grad
  print("a:",a)
  print("b:",b)
# Out:
# mse: 0.4040743522673057
# a: 0.7375484867128349
# b: 1.8003932572518386
# mse: 0.40391183851358947
# a: 0.7387739215434679
# b: 1.800053831453664
# mse: 0.40375042180787785
# a: 0.7399952132253786
# b: 1.7997155532412499
# mse: 0.40359009474455726
# a: 0.7412123757663961
# b: 1.7993784187346522
# mse: 0.4034308499680037
# a: 0.742425423126989
# b: 1.799042424067045
# mse: 0.40327268017224666
# a: 0.7436343692204265
# b: 1.7987075653846758
# mse: 0.40311557810063803
# a: 0.7448392279129374
# b: 1.7983738388468216
# mse: 0.4029595365455103
# a: 0.7460400130238694
# b: 1.7980412406257447
# mse: 0.4028045483478559
# a: 0.7472367383258472
# b: 1.7977097669066486
# mse: 0.40265060639699124
# a: 0.7484294175449314
# b: 1.7973794138876351

# %%
r2=r2_score(y,y_pred)
print(f'R2 score:{r2:.2f}')
mse=mean_squared_error(y,y_pred)
print(f'Mean Squared Error:{mse:.2f}')
# Out:
# R2 score:0.93
# Mean Squared Error:0.40

# %%
import matplotlib.pyplot as plt
plt.scatter(df['X'],df['Y'])
plt.plot(x,y_pred)
plt.show()

# %% [markdown]
# logistic regression

# %%
import pandas as pd
data = {'StudyHours': [15, 29, 28, 31, 35],
        'Result': ['Fail', 'Fail', 'Pass', 'Pass', 'Pass']}
df = pd.DataFrame(data)
print(df)
# Out:
#    StudyHours Result
# 0          15   Fail
# 1          29   Fail
# 2          28   Pass
# 3          31   Pass
# 4          35   Pass

# %%
x= df[['StudyHours']]
y= df['Result']

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Result']=l.fit_transform(df['Result'])
y=l.fit_transform(y)
print(df)
# Out:
#    StudyHours  Result
# 0          15       0
# 1          29       0
# 2          28       1
# 3          31       1
# 4          35       1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred,zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.75      0.50      0.33         2
# weighted avg       0.75      0.50      0.33         2

# %%
import matplotlib.pyplot as plt
y_pred=model.predict(x)
y_pred_prob = model.predict_proba(x)
plt.xlabel('StudyHours')
plt.ylabel('Result')
plt.scatter(x,y)
plt.plot(x,y_pred_prob[:, 1] )
plt.show()
